# %%
import pandas as pd

# %% [markdown]
# ## Question 1

# %% [markdown]
# ####  Find out how many males and females participated in the test.

# %%
data=pd.read_csv(r"E:\DATA ANALYSIS\Dataset\StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# 5    female        group B                 high school  free/reduced
# 6    female        group B            some high school  free/reduced
# 7    female        group D          associate's degree  free/reduced
# 8    female        group D            some high school  free/reduced
# 9    female        group C                 high school      standard
# 10   female        group C            some high school  free/reduced
# 11   female        group D           bachelor's degree  free/reduced
# 12   female        group B            some high school      standard
# ...

# %%
pd.value_counts(data['gender'])
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# ####  What do you think about the students' parental level of education?

# %%
pd.value_counts(data['parental level of education'])
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['parental level of education'].mode()   # Most repeated parental level of education is some college.
# Out:
# 0    some college
# dtype: object

# %%
# Most number of parents are studied in some colleges and had a associate's degree. Only 59 parents had Master's degree. Among 1000 data 196 people are educated till high school.

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### Who scores the most on average for maths, reading and writing based on: *Gender*

# %%
data.groupby('gender')['math score'].mean()
# Out:
# gender
# female    63.376448
# male      68.821577
# Name: math score, dtype: float64

# %%
# Male students scored more average marks in Maths than female students

# %%
data.groupby('gender')['reading score'].mean()
# Out:
# gender
# female    72.590734
# male      65.545643
# Name: reading score, dtype: float64

# %%
# Female students scored more average marks in Reading than male students

# %%
data.groupby('gender')['writing score'].mean()
# Out:
# gender
# female    72.467181
# male      63.446058
# Name: writing score, dtype: float64

# %%
# Female students scored more average marks in Writing than male students

# %% [markdown]
# #### Who scores the most on average for maths, reading and writing based on: *Test Preparation Course*

# %%
data.groupby('test preparation course')['math score'].mean()
# Out:
# test preparation course
# completed    69.96648
# none         63.78972
# Name: math score, dtype: float64

# %%
# The students who are completed the test preparation course scored more average marks in Maths.

# %%
data.groupby('test preparation course')['reading score'].mean()
# Out:
# test preparation course
# completed    74.175978
# none         66.417445
# Name: reading score, dtype: float64

# %%
# The students who are completed the test preparation course scored more average marks in Reading.

# %%
data.groupby('test preparation course')['writing score'].mean()
# Out:
# test preparation course
# completed    74.684358
# none         64.457944
# Name: writing score, dtype: float64

# %%
# The students who are completed the test preparation course scored more average marks in Writing.

# %% [markdown]
# ## Question 4

# %% [markdown]
# #### What do you think about the scoring variation for math, reading and writing based on: *Gender*

# %%
data.groupby('gender')['math score'].std()
# Out:
# gender
# female    16.029928
# male      14.556411
# Name: math score, dtype: float64

# %%
# Standard deviation of the maths score of female students is more than that of male students.The maths score of female students is more deviated from the average compared to the male students.

# %%
data.groupby('gender')['reading score'].std()
# Out:
# gender
# female    14.411018
# male      14.149594
# Name: reading score, dtype: float64

# %%
# Standard deviation of the reading score of female students is more than that of male students.The reading score of female students is more deviated from the average compared to the male students.But the difference is in smaller amount.

# %%
data.groupby('gender')['writing score'].std()
# Out:
# gender
# female    14.844842
# male      14.227225
# Name: writing score, dtype: float64

# %%
# Standard deviation of the writing score of female students is more than that of male students.The writing score of female students is more deviated from the average compared to the male students.

# %% [markdown]
# #### What do you think about the scoring variation for math, reading and writing baesd on: *Test Preparation Course*

# %%
data.groupby('test preparation course')['math score'].std()
# Out:
# test preparation course
# completed    14.521847
# none         15.705689
# Name: math score, dtype: float64

# %%
# The students who are not taken the test preparation course have more standard deviation in maths score than students who are completed the test preparation course.

# %%
data.groupby('test preparation course')['reading score'].std()
# Out:
# test preparation course
# completed    13.537572
# none         14.608896
# Name: reading score, dtype: float64

# %%
# The students who are not taken the test preparation course have more standard deviation in reading score than students who are completed the test preparation course.

# %%
data.groupby('test preparation course')['writing score'].std()
# Out:
# test preparation course
# completed    13.236412
# none         15.041667
# Name: writing score, dtype: float64

# %%
# The students who are not taken the test preparation course have more standard deviation in writing score than students who are completed the test preparation course.

# %% [markdown]
# ## Question 5

# %% [markdown]
# ####  The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.

# %%
data.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
Q1=(1000+1)/4
Q1                        # Position of first quartile
# Out:
# 250.25

# %%
data.nlargest(250,['math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
# 513  female        group E           bachelor's degree      standard
# 514  female        group E                 high school      standard
# 995    male        group E                some college      standard
# 512  female        group D                some college      standard
# 993    male        group C                some college      standard
# 994    male        group C          associate's degree      standard
# ...

# %%
# These are the top 25% of students based on their scores in Maths.
